# %% [markdown]
# <a href="https://colab.research.google.com/github/afifahsuaib/Pemrograman_python/blob/main/Tugas13_Afifah_Amatulla_Suaib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos(frek,tipe,ht,hr,d):
    if frek in range(150,1501):
        Ca=69.55
        Cb=26.16
    elif frek in range(1501,2001):
        Ca=46.3
        Cb=33.9
    
    if tipe=='urban' :
        Cm=0
    elif tipe=='suburban' :
        Cm= -2*((np.log10((frek/28)**2))-5.4)
    elif tipe=='open' :
        Cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
    else :
        Cm='tipe salah'
    
    ahr = (1.1*np.log10(frek)-0.7)*hr-(1.56*np.log10(frek)-1.8)
    Lp = Ca+(Cb*np.log10(frek))-(13.83*np.log(ht))-ahr+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
    return Lp

# %% [markdown]
# GRAFIK 1
# Frekuensi 1800 MHz

# %%
f=1800 #MHz
tipe1='urban'
tipe2='suburban'
tipe3='open'
tower=80 #m
user=1.5 #m
dmin=200 #m
dmax=700 #m
N=200 #titik
d=np.random.randint(dmin,dmax,N)

# %%
PlUrban=cos(f,tipe1,tower,user,d)
PlSuburban= cos (f,tipe2, tower,user, d)
PlOpen= cos (f,tipe3, tower,user, d)

# %%
plt.figure()
plt.plot(d,PlUrban, label="Urban")
plt.plot(d,PlSuburban, label="Suburban")
plt.plot(d,PlOpen, label="Open")
plt.legend()
plt.title("Model Frekuensi 1800 MHz")
plt.xlabel("Jarak (m)")
plt.ylabel("Path Loss (dB)")
plt.show()

# %%
d_sort=d[np.argsort(d)]
Urban_sort= PlUrban[np.argsort(d)]
Suburban_sort = PlSuburban[np.argsort(d)]
Open_sort = PlOpen[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,Urban_sort, label= "Urban")
plt.plot(d_sort,Suburban_sort, label= "Suburban")
plt.plot(d_sort,Open_sort, label= "Open")
plt.legend()
plt.title("Model Frekuensi 1800 MHz")
plt.xlabel("Jarak (m)")
plt.ylabel("Path Loss (dB)")
plt.show()

# %% [markdown]
# GRAFIK II

# %%
f1= 700 #MHz
f2= 900 #MHz
f3= 1800 #MHz
tipee= "urban"
tower=80 #m
user=1.5 #m
dmin=200 #m
dmax=700 #m
N=200 #titik
d=np.random.randint(dmin,dmax,N)

# %%
Plf1=cos(f1,tipee,tower,user,d)
Plf2=cos(f2,tipee, tower,user, d)
Plf3=cos(f3,tipee, tower,user, d)

# %%
plt.figure()
plt.plot(d,Plf1, label="700 MHz")
plt.plot(d,Plf2, label="900 MHz")
plt.plot(d,Plf3, label="1800 MHz")
plt.legend()
plt.title("Model Urban")
plt.xlabel("Jarak (m)")
plt.ylabel("Path Loss (dB)")
plt.show()

# %%
d_sort=d[np.argsort(d)]
f1_sort= Plf1[np.argsort(d)]
f2_sort= Plf2[np.argsort(d)]
f3_sort= Plf3[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,f1_sort, label= "700 MHz")
plt.plot(d_sort,f2_sort, label= "900 MHz")
plt.plot(d_sort,f3_sort, label= "1800 MHz")
plt.legend()
plt.title("Model Urban")
plt.xlabel("Jarak (m)")
plt.ylabel("Path Loss (dB)")
plt.show()
